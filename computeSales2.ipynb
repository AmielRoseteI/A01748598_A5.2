# %%
#Google Drive Connection
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import time
import os

# %%
PRICE_FILE = "/content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/TC1.ProductList.json"
SALES_FILE = "/content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/TC2.Sales.json"
OUTPUT_FILE = "/content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/SalesResults.txt"

# %%
def load_json(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            return json.load(file)
    except FileNotFoundError:
        print(f"Error: File not found - {file_path}")
    except json.JSONDecodeError:
        print(f"Error: Invalid JSON format in {file_path}")
    return None

# %%
def compute_total_sales(products, sales):
    product_prices = {item["title"]: item["price"] for item in products}
    total_cost = 0
    errors = []

    for sale in sales:
        product_name = sale["Product"]
        quantity = sale["Quantity"]

        if product_name in product_prices:
            total_cost += product_prices[product_name] * quantity
        else:
            errors.append(f"Warning: Product '{product_name}' not found in catalog.")

    return total_cost, errors

# %%
def save_results(file_path, total_cost, errors, elapsed_time):
    with open(file_path, 'w', encoding='utf-8') as file:
        file.write(f"Total Sales Cost: ${total_cost:.2f}\n")
        file.write(f"Execution Time: {elapsed_time:.4f} seconds\n")
        if errors:
            file.write("\nErrors:\n")
            for error in errors:
                file.write(f"{error}\n")

# %%
def main():
    start_time = time.time()

    products = load_json(PRICE_FILE)
    sales = load_json(SALES_FILE)

    if products is None or sales is None:
        print("Error: Could not load JSON data. Exiting.")
        return

    total_cost, errors = compute_total_sales(products, sales)

    elapsed_time = time.time() - start_time

    print(f"Total Sales Cost: ${total_cost:.2f}")
    print(f"Execution Time: {elapsed_time:.4f} seconds")
    if errors:
        print("\nErrors:")
        for error in errors:
            print(error)

    save_results(OUTPUT_FILE, total_cost, errors, elapsed_time)
    print(f"Results saved to {OUTPUT_FILE}")

# %%
main()
# Out:
# Total Sales Cost: $166568.23
# Execution Time: 1.4842 seconds
# Results saved to /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/SalesResults.txt

# %%
pip install flake8
# Out:
# Collecting flake8
#   Downloading flake8-7.1.1-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting mccabe<0.8.0,>=0.7.0 (from flake8)
#   Downloading mccabe-0.7.0-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting pycodestyle<2.13.0,>=2.12.0 (from flake8)
#   Downloading pycodestyle-2.12.1-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting pyflakes<3.3.0,>=3.2.0 (from flake8)
#   Downloading pyflakes-3.2.0-py2.py3-none-any.whl.metadata (3.5 kB)
# Downloading flake8-7.1.1-py2.py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 3.5 MB/s eta 0:00:00
# Downloading mccabe-0.7.0-py2.py3-none-any.whl (7.3 kB)
# Downloading pycodestyle-2.12.1-py2.py3-none-any.whl (31 kB)
# Downloading pyflakes-3.2.0-py2.py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.3 MB/s eta 0:00:00
# Installing collected packages: pyflakes, pycodestyle, mccabe, flake8
# Successfully installed flake8-7.1.1 mccabe-0.7.0 pycodestyle-2.12.1 pyflakes-3.2.0

# %%
CHECK_FILE = "/content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb"

# %%
# !python "/content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb" "/content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/TC1.ProductList.json" "/content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/TC1.Sales.json"

# %%
# !flake8 "/content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb"
# Out:
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:12: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:14: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:31: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:33: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:44: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:53: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:67: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:70: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:80: E501 line too long (101489 > 79 characters)
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:87: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:119: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:132: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:140: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:150: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:165: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:177: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:193: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:201: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:212: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:220: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:234: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:241: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:259: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:261: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:272: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:278: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:293: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:301: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:313: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:340: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:356: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:366: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:371: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:383: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:397: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:407: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:411: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:421: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:425: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:432: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:447: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:473: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:482: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:507: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:518: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:558: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:568: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:584: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:593: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:600: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:609: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:616: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:755: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:764: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:794: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:829: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:863: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:876: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:883: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:892: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:909: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:925: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:938: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:949: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:955: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:970: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:986: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:996: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1001: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1013: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1027: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1037: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1041: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1051: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1054: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1061: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1076: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1102: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1111: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1137: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1155: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1157: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1167: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1171: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1184: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1191: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1200: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1316: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1425: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1536: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1547: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1553: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1568: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1584: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1594: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1599: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1611: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1625: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1635: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1639: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1649: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1652: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1659: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1674: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1700: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1709: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1735: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1753: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1755: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1765: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1769: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1782: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1789: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1798: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1829: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1842: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1907: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1946: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1980: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:2040: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:2077: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:2143: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:2162: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:2173: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:2179: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:2194: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1: