# %%
#Google Drive Connection
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
import time
import os

# %%
PRICE_FILE = "/content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/TC1.ProductList.json"
SALES_FILE = "/content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/TC1.Sales.json"
OUTPUT_FILE = "/content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/SalesResults.txt"

# %%
def load_json(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            return json.load(file)
    except FileNotFoundError:
        print(f"Error: File not found - {file_path}")
    except json.JSONDecodeError:
        print(f"Error: Invalid JSON format in {file_path}")
    return None

# %%
def compute_total_sales(products, sales):
    product_prices = {item["title"]: item["price"] for item in products}
    total_cost = 0
    errors = []

    for sale in sales:
        product_name = sale["Product"]
        quantity = sale["Quantity"]

        if product_name in product_prices:
            total_cost += product_prices[product_name] * quantity
        else:
            errors.append(f"Warning: Product '{product_name}' not found in catalog.")

    return total_cost, errors

# %%
def save_results(file_path, total_cost, errors, elapsed_time):
    with open(file_path, 'w', encoding='utf-8') as file:
        file.write(f"Total Sales Cost: ${total_cost:.2f}\n")
        file.write(f"Execution Time: {elapsed_time:.4f} seconds\n")
        if errors:
            file.write("\nErrors:\n")
            for error in errors:
                file.write(f"{error}\n")

# %%
def main():
    start_time = time.time()

    products = load_json(PRICE_FILE)
    sales = load_json(SALES_FILE)

    if products is None or sales is None:
        print("Error: Could not load JSON data. Exiting.")
        return

    total_cost, errors = compute_total_sales(products, sales)

    elapsed_time = time.time() - start_time

    print(f"Total Sales Cost: ${total_cost:.2f}")
    print(f"Execution Time: {elapsed_time:.4f} seconds")
    if errors:
        print("\nErrors:")
        for error in errors:
            print(error)

    save_results(OUTPUT_FILE, total_cost, errors, elapsed_time)
    print(f"Results saved to {OUTPUT_FILE}")

# %%
main()
# Out:
# Total Sales Cost: $2481.86
# Execution Time: 0.0247 seconds
# Results saved to /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/SalesResults.txt

# %%
pip install flake8
# Out:
# Requirement already satisfied: flake8 in /usr/local/lib/python3.10/dist-packages (7.1.1)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from flake8) (0.7.0)
# Requirement already satisfied: pycodestyle<2.13.0,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from flake8) (2.12.1)
# Requirement already satisfied: pyflakes<3.3.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from flake8) (3.2.0)

# %%
CHECK_FILE = "/content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb"

# %%
# !python "/content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb" "/content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/TC1.ProductList.json" "/content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/TC1.Sales.json"

# %%
# !flake8 "/content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb"
# Out:
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:12: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:14: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:31: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:33: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:44: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:53: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:67: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:70: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:80: E501 line too long (7319 > 79 characters)
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:87: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:119: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:132: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:140: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:150: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:165: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:177: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:193: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:201: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:212: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:220: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:234: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:241: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:259: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:262: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:273: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:279: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:294: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:302: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:314: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:341: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:357: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:367: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:372: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:384: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:398: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:408: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:412: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:422: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:426: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:433: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:448: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:474: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:483: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:508: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:519: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:559: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:569: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:585: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:594: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:601: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:610: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:617: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:756: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:765: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:795: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:830: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:864: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:877: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:884: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:893: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:910: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:926: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:939: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:950: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:956: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:971: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:987: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:997: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1002: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1014: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1028: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1038: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1042: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1052: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1054: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1061: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1076: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1102: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1111: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1137: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1155: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1158: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1168: E231 missing whitespace after ':'
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1:1172: E231 missing whitespace after ','
# /content/drive/MyDrive/Colab Notebooks/Pruebas de SW y Calidad/Tarea 5.2/computeSales.ipynb:1: